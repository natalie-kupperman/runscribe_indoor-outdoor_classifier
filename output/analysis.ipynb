# %% [markdown]
# ## Runscribe: Comparison of Data on Treadmill & Outdoors
#
# ### data analysis

# %%
# import dependencies
import pandas as pd
import numpy as np
import scipy
from scipy import stats
from scipy.stats import variation

# %% [markdown]
# ### cleaning and descriptives for outdoor runs

# %%
# read in outdoor_df
outdoor_df = pd.read_csv("outdoor_df.csv")
outdoor_df.head()
# Out:
#    timestamp  step  stride_pace  step_rate  stride_length  contact_time  \
# 0        511     2       1.7899   201.6807          1.065           310
# 1       1106     3       1.5258   171.9198          1.065           379
# 2       1804     4       1.0714   120.7243          1.065           643
# 3       2798     5       1.1464   129.1712          1.065           644
# 4       3727     6       1.5236   171.6738          1.065           434
#
#    flight_ratio  power    shock  impact_gs   ...     debug_2  flight_time  \
# 0           0.0    NaN  14.2155    13.0703   ...      3.6250          -13
# 1           0.0    NaN  10.8569    10.3164   ...      8.6094          -30
# 2           0.0    NaN  13.4718    12.7734   ...     11.9375         -146
# 3           0.0    NaN   5.6738     3.3516   ...      7.8398         -180
# 4           0.0    NaN   5.1106     1.5586   ...      4.8633          -85
#
#    stride_angle  walking  footstrike_type_new  laterality        date  \
# 0        0.0892      NaN               8.3526        left  2018-03-30
# 1        0.4750      NaN               7.5634        left  2018-03-30
# 2       11.1087      NaN               4.0725        left  2018-03-30
# 3       16.6177      NaN               5.1109        left  2018-03-30
# 4        3.8075      NaN               8.2728        left  2018-03-30
#
#    injury_status  subject_id   medium
# 0        healthy           4  outdoor
# 1        healthy           4  outdoor
# 2        healthy           4  outdoor
# 3        healthy           4  outdoor
# 4        healthy           4  outdoor
#
# [5 rows x 33 columns]

# %%
# rows and columns
outdoor_df.shape
# Out:
# (10688, 33)

# %%
# variables
outdoor_df.columns
# Out:
# Index(['timestamp', 'step', 'stride_pace', 'step_rate', 'stride_length',
#        'contact_time', 'flight_ratio', 'power', 'shock', 'impact_gs',
#        'braking_gs', 'footstrike_type', 'pronation_excursion_fs_mp',
#        'max_pronation_velocity', 'step_length', 'pronation_excursion_mp_to',
#        'stance_excursion_fs_mp', 'stance_excursion_mp_to', 'split_stride_pace',
#        'cycle_time', 'split_cycle_time', 'contact_ratio', 'debug_1', 'debug_2',
#        'flight_time', 'stride_angle', 'walking', 'footstrike_type_new',
#        'laterality', 'date', 'injury_status', 'subject_id', 'medium'],
#       dtype='object')

# %%
# number of observations for each subject
outdoor_df.subject_id.value_counts()
# Out:
# 27    2492
# 4     2472
# 23    2197
# 16    2043
# 12    1484
# Name: subject_id, dtype: int64

# %%
# drop unnessary columns
outdoor_df = outdoor_df.drop(['walking', 'debug_1', 'debug_2', 'power', 'timestamp'], axis = 1)
outdoor_df.head()
# Out:
#    step  stride_pace  step_rate  stride_length  contact_time  flight_ratio  \
# 0     2       1.7899   201.6807          1.065           310           0.0
# 1     3       1.5258   171.9198          1.065           379           0.0
# 2     4       1.0714   120.7243          1.065           643           0.0
# 3     5       1.1464   129.1712          1.065           644           0.0
# 4     6       1.5236   171.6738          1.065           434           0.0
#
#      shock  impact_gs  braking_gs  footstrike_type   ...     split_cycle_time  \
# 0  14.2155    13.0703      5.5898               12   ...                  595
# 1  10.8569    10.3164      3.3828               11   ...                  698
# 2  13.4718    12.7734      4.2813                5   ...                  994
# 3   5.6738     3.3516      4.5781                7   ...                  929
# 4   5.1106     1.5586      4.8672               12   ...                  699
#
#    contact_ratio  flight_time  stride_angle  footstrike_type_new  laterality  \
# 0       108.7719          -13        0.0892               8.3526        left
# 1       118.8088          -30        0.4750               7.5634        left
# 2       183.1909         -146       11.1087               4.0725        left
# 3       225.9649         -180       16.6177               5.1109        left
# 4       163.7736          -85        3.8075               8.2728        left
#
#          date  injury_status  subject_id   medium
# 0  2018-03-30        healthy           4  outdoor
# 1  2018-03-30        healthy           4  outdoor
# 2  2018-03-30        healthy           4  outdoor
# 3  2018-03-30        healthy           4  outdoor
# 4  2018-03-30        healthy           4  outdoor
#
# [5 rows x 28 columns]

# %%
# drop observations where flight_ratio is less than 10 (walking)
outdoor_running_df = outdoor_df[outdoor_df.flight_ratio > 10]

#check that observations were dropped
outdoor_running_df["flight_ratio"].min()
# Out:
# 10.028700000000001

# %%
# group data analysis by subject
outdoor_groupby_subject = outdoor_running_df.groupby('subject_id')

# %%
# descriptive statistics by subject
outdoor_describe = outdoor_groupby_subject.describe(percentiles=[])\
                   .reset_index()

outdoor_describe
# Out:
#   subject_id braking_gs                                                 \
#                   count       mean       std     min      50%      max
# 0          4     2125.0  10.527694  2.909489  0.6367  10.3633  15.9766
# 1         12     1061.0  12.585500  2.659520  1.6875  13.2305  15.9961
# 2         16     1877.0  11.105368  2.796769  4.2969  11.2734  15.9805
# 3         23     2153.0   9.886145  2.638059  5.3867   9.2227  15.9922
# 4         27     2157.0   9.870123  2.958839  4.8828   9.1797  15.9922
#
#   contact_ratio                        ...   stride_length                  \
#           count       mean       std   ...             std     min     50%
# 0        2125.0  67.092987  4.689124   ...        0.158584  1.0853  2.2888
# 1        1061.0  58.566143  9.217930   ...        1.189760  1.0062  2.7887
# 2        1877.0  69.024200  6.673315   ...        0.103192  1.8872  2.6475
# 3        2153.0  62.230966  5.994010   ...        0.211812  1.2059  2.4297
# 4        2157.0  71.070569  7.211966   ...        0.194075  0.5893  2.0888
#
#           stride_pace
#       max       count      mean       std     min     50%     max
# 0  3.0586      2125.0  3.241155  0.234000  1.4356  3.2112  4.2952
# 1  5.8896      1061.0  4.048926  1.655650  1.3932  3.8767  9.0215
# 2  3.0509      1877.0  3.587940  0.175599  2.6769  3.6030  4.2511
# 3  3.4033      2153.0  3.420573  0.305129  1.5343  3.3780  4.6942
# 4  2.8886      2157.0  3.004906  0.299621  0.7964  2.9668  4.2479
#
# [5 rows x 139 columns]

# %%
outdoor_mean = outdoor_groupby_subject.mean().add_suffix('_mean')\
               .reset_index()
outdoor_mean
# Out:
#    subject_id   step_mean  stride_pace_mean  step_rate_mean  \
# 0           4  709.323294          3.241155      168.416157
# 1          12  485.090481          4.048926      166.484367
# 2          16  529.086308          3.587940      163.193955
# 3          23  546.237343          3.420573      166.797297
# 4          27  650.439963          3.004906      170.866630
#
#    stride_length_mean  contact_time_mean  flight_ratio_mean  shock_mean  \
# 0            2.309117         285.880000          19.731211   14.850554
# 1            2.921104         264.995287          26.624048   18.086746
# 2            2.637614         299.795951          18.459271   15.462385
# 3            2.460639         275.443103          23.393806   14.194952
# 4            2.109433         291.166898          17.070546   14.458229
#
#    impact_gs_mean  braking_gs_mean            ...             \
# 0        9.972030        10.527694            ...
# 1       12.778077        12.585500            ...
# 2       10.223779        11.105368            ...
# 3        9.778390         9.886145            ...
# 4       10.106231         9.870123            ...
#
#    pronation_excursion_mp_to_mean  stance_excursion_fs_mp_mean  \
# 0                        0.297388                    26.564310
# 1                       -5.249249                    15.549934
# 2                        4.231296                    26.048063
# 3                       12.153834                    19.206575
# 4                       14.902021                    14.929890
#
#    stance_excursion_mp_to_mean  split_stride_pace_mean  cycle_time_mean  \
# 0                    64.332242                3.241155       712.752000
# 1                    36.247697                4.048926       721.947220
# 2                    58.154061                3.587940       735.589771
# 3                    61.683034                3.420573       719.714352
# 4                    62.511791                3.004906       702.785350
#
#    split_cycle_time_mean  contact_ratio_mean  flight_time_mean  \
# 0             712.752000           67.092987         70.248000
# 1             721.947220           58.566143         95.725730
# 2             735.589771           69.024200         67.765051
# 3             719.714352           62.230966         84.167673
# 4             702.785350           71.070569         59.978674
#
#    stride_angle_mean  footstrike_type_new_mean
# 0           1.235843                  2.429171
# 1           2.527976                  5.568268
# 2           1.035891                  2.576302
# 3           1.676274                  4.526125
# 4           1.062641                  5.744982
#
# [5 rows x 24 columns]

# %%
outdoor_sd = outdoor_groupby_subject.std().add_suffix('_sd')\
             .reset_index()
outdoor_sd
# Out:
#    subject_id     step_sd  stride_pace_sd  step_rate_sd  stride_length_sd  \
# 0           4  312.891610        0.234000      2.987030          0.158584
# 1          12  292.212825        1.655650      7.534766          1.189760
# 2          16  298.216763        0.175599      3.114614          0.103192
# 3          23  317.088845        0.305129      3.271075          0.211812
# 4          27  379.364728        0.299621      4.488585          0.194075
#
#    contact_time_sd  flight_ratio_sd  shock_sd  impact_gs_sd  braking_gs_sd  \
# 0        13.461398         3.335133  3.314791      3.576717       2.909489
# 1        35.665704         9.484774  2.469600      2.118382       2.659520
# 2        19.601152         4.697403  3.268043      3.754300       2.796769
# 3        16.349791         4.482078  3.420544      3.590057       2.638059
# 4        19.226942         5.187551  3.313210      3.422332       2.958839
#
#             ...            pronation_excursion_mp_to_sd  \
# 0           ...                                8.140969
# 1           ...                               57.191610
# 2           ...                                3.665315
# 3           ...                                7.060475
# 4           ...                                5.068085
#
#    stance_excursion_fs_mp_sd  stance_excursion_mp_to_sd  split_stride_pace_sd  \
# 0                   7.200345                   7.151112              0.234000
# 1                  33.133749                  25.230977              1.655650
# 2                   4.537285                   3.378618              0.175599
# 3                   6.706002                   6.464045              0.305129
# 4                  10.316032                  12.856363              0.299621
#
#    cycle_time_sd  split_cycle_time_sd  contact_ratio_sd  flight_time_sd  \
# 0      13.119190            13.119190          4.689124       11.834075
# 1      25.917668            25.917668          9.217930       32.425229
# 2      14.072954            14.072954          6.673315       17.069521
# 3      14.204712            14.204712          5.994010       16.394878
# 4      18.411696            18.411696          7.211966       18.464239
#
#    stride_angle_sd  footstrike_type_new_sd
# 0         0.395863                2.052099
# 1         3.837816                9.443118
# 2         0.499959                1.293126
# 3         0.592439                1.911210
# 4         0.741174                2.940069
#
# [5 rows x 24 columns]

# %%
# median descriptive statistic by subject
outdoor_median = outdoor_groupby_subject.median().add_suffix('_median')\
                 .reset_index()
outdoor_median
# Out:
#    subject_id  step_median  stride_pace_median  step_rate_median  \
# 0           4          709              3.2112          168.0672
# 1          12          462              3.8767          165.7459
# 2          16          550              3.6030          163.2653
# 3          23          547              3.3780          166.6667
# 4          27          683              2.9668          170.4545
#
#    stride_length_median  contact_time_median  flight_ratio_median  \
# 0                2.2888                  285              20.1117
# 1                2.7887                  270              25.3444
# 2                2.6475                  296              18.7675
# 3                2.4297                  274              23.9669
# 4                2.0888                  295              15.9420
#
#    shock_median  impact_gs_median  braking_gs_median  \
# 0       15.0736           10.0625            10.3633
# 1       18.4625           13.1055            13.2305
# 2       15.8401           10.5898            11.2734
# 3       14.2427            9.6055             9.2227
# 4       14.7502           10.0938             9.1797
#
#               ...              pronation_excursion_mp_to_median  \
# 0             ...                                       -1.5095
# 1             ...                                      -33.6959
# 2             ...                                        4.6506
# 3             ...                                       11.5295
# 4             ...                                       14.7303
#
#    stance_excursion_fs_mp_median  stance_excursion_mp_to_median  \
# 0                        28.3783                        63.2390
# 1                        12.2495                        32.9838
# 2                        26.7331                        58.1829
# 3                        20.0994                        60.5517
# 4                        18.4294                        61.6202
#
#    split_stride_pace_median  cycle_time_median  split_cycle_time_median  \
# 0                    3.2112                714                      714
# 1                    3.8767                724                      724
# 2                    3.6030                735                      735
# 3                    3.3780                720                      720
# 4                    2.9668                704                      704
#
#    contact_ratio_median  flight_time_median  stride_angle_median  \
# 0               66.5049                  72               1.2382
# 1               59.5506                  91               1.6286
# 2               68.2353                  69               1.0065
# 3               61.3333                  86               1.6810
# 4               72.4638                  55               0.8164
#
#    footstrike_type_new_median
# 0                      1.9122
# 1                      6.5089
# 2                      2.3811
# 3                      4.2717
# 4                      4.7476
#
# [5 rows x 24 columns]

# %%
# calculate COV
outdoor_cov = outdoor_groupby_subject\
              .aggregate(lambda x: scipy.stats.variation(x, axis=None))\
              .add_suffix('_cov')\
              .reset_index()

outdoor_cov

#outdoor_cov.to_csv("outdoor_cov.csv")
# Out:
# /Users/NatalieKramer/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
#    subject_id  step_cov  stride_pace_cov  step_rate_cov  stride_length_cov  \
# 0           4  0.441009         0.072180       0.017732           0.068661
# 1          12  0.602104         0.408718       0.045237           0.407106
# 2          16  0.563495         0.048928       0.019080           0.039113
# 3          23  0.580362         0.089183       0.019607           0.086060
# 4          27  0.583108         0.099687       0.026263           0.091982
#
#    contact_time_cov  flight_ratio_cov  shock_cov  impact_gs_cov  \
# 0          0.047077          0.168989   0.223157       0.358590
# 1          0.134527          0.356080   0.136478       0.165704
# 2          0.065364          0.254406   0.211298       0.367115
# 3          0.059344          0.191548   0.240913       0.367057
# 4          0.066019          0.303819   0.229104       0.338557
#
#    braking_gs_cov           ...             pronation_excursion_mp_to_cov  \
# 0        0.276300           ...                                 27.368492
# 1        0.211217           ...                                -10.890062
# 2        0.251772           ...                                  0.866008
# 3        0.266782           ...                                  0.580791
# 4        0.299708           ...                                  0.340015
#
#    stance_excursion_fs_mp_cov  stance_excursion_mp_to_cov  \
# 0                    0.270990                    0.111133
# 1                    2.129792                    0.695743
# 2                    0.174143                    0.058082
# 3                    0.349070                    0.104770
# 4                    0.690805                    0.205615
#
#    split_stride_pace_cov  cycle_time_cov  split_cycle_time_cov  \
# 0               0.072180        0.018402              0.018402
# 1               0.408718        0.035883              0.035883
# 2               0.048928        0.019126              0.019126
# 3               0.089183        0.019732              0.019732
# 4               0.099687        0.026192              0.026192
#
#    contact_ratio_cov  flight_time_cov  stride_angle_cov  \
# 0           0.069873         0.168422          0.320243
# 1           0.157319         0.338571          1.517422
# 2           0.096655         0.251826          0.482508
# 3           0.096296         0.194743          0.353344
# 4           0.101453         0.307775          0.697321
#
#    footstrike_type_new_cov
# 0                 0.844574
# 1                 1.695081
# 2                 0.501797
# 3                 0.422164
# 4                 0.511644
#
# [5 rows x 24 columns]

# %%
outdoor_compare = pd.merge(outdoor_mean, outdoor_sd,
                           on = "subject_id", how = 'left')

outdoor_compare = pd.merge(outdoor_compare, outdoor_cov,
                           on = "subject_id", how = 'left')

outdoor_compare
# Out:
#    subject_id   step_mean  stride_pace_mean  step_rate_mean  \
# 0           4  709.323294          3.241155      168.416157
# 1          12  485.090481          4.048926      166.484367
# 2          16  529.086308          3.587940      163.193955
# 3          23  546.237343          3.420573      166.797297
# 4          27  650.439963          3.004906      170.866630
#
#    stride_length_mean  contact_time_mean  flight_ratio_mean  shock_mean  \
# 0            2.309117         285.880000          19.731211   14.850554
# 1            2.921104         264.995287          26.624048   18.086746
# 2            2.637614         299.795951          18.459271   15.462385
# 3            2.460639         275.443103          23.393806   14.194952
# 4            2.109433         291.166898          17.070546   14.458229
#
#    impact_gs_mean  braking_gs_mean           ...             \
# 0        9.972030        10.527694           ...
# 1       12.778077        12.585500           ...
# 2       10.223779        11.105368           ...
# 3        9.778390         9.886145           ...
# 4       10.106231         9.870123           ...
#
#    pronation_excursion_mp_to_cov  stance_excursion_fs_mp_cov  \
# 0                      27.368492                    0.270990
# 1                     -10.890062                    2.129792
# 2                       0.866008                    0.174143
# 3                       0.580791                    0.349070
# 4                       0.340015                    0.690805
#
#    stance_excursion_mp_to_cov  split_stride_pace_cov  cycle_time_cov  \
# 0                    0.111133               0.072180        0.018402
# 1                    0.695743               0.408718        0.035883
# 2                    0.058082               0.048928        0.019126
# 3                    0.104770               0.089183        0.019732
# 4                    0.205615               0.099687        0.026192
#
#    split_cycle_time_cov  contact_ratio_cov  flight_time_cov  stride_angle_cov  \
# 0              0.018402           0.069873         0.168422          0.320243
# 1              0.035883           0.157319         0.338571          1.517422
# 2              0.019126           0.096655         0.251826          0.482508
# 3              0.019732           0.096296         0.194743          0.353344
# 4              0.026192           0.101453         0.307775          0.697321
#
#    footstrike_type_new_cov
# 0                 0.844574
# 1                 1.695081
# 2                 0.501797
# 3                 0.422164
# 4                 0.511644
#
# [5 rows x 70 columns]

# %%
# get steps for outdoor run to compare to treadmill run
outdoor_max = outdoor_groupby_subject.max()
outdoor_max['step']
# Out:
# subject_id
# 4     1254
# 12    1060
# 16    1024
# 23    1099
# 27    1276
# Name: step, dtype: int64

# %% [markdown]
# ### cleaning and descriptives for treadmill runs

# %%
# read in treadmill_df
treadmill_df = pd.read_csv("treadmill_df.csv")
treadmill_df.head()
# Out:
#    timestamp  step  stride_pace  step_rate  stride_length  contact_time  \
# 0        408     1       1.7251   160.2136         1.2921           460
# 1       1157     2       1.9170   178.0415         1.2921           405
# 2       1831     3       1.7159   159.3625         1.2921           394
# 3       2584     4       1.3334   123.8390         1.2921           614
# 4       3553     5       1.3760   127.7955         1.2921           599
#
#    flight_ratio  power    shock  impact_gs    ...      debug_2  flight_time  \
# 0           0.0    NaN   9.2403     8.8711    ...       2.4727          -86
# 1           0.0    NaN   8.5985     8.1133    ...       1.3242          -68
# 2           0.0    NaN   9.3279     8.8203    ...       3.8320          -18
# 3           0.0    NaN  10.7894     1.8984    ...       0.4961         -130
# 4           0.0    NaN   9.0301     5.6172    ...       7.4453         -130
#
#    stride_angle  walking  footstrike_type_new  laterality        date  \
# 0        3.2140      NaN               8.1634        left  2018-04-07
# 1        2.0107      NaN               8.7936        left  2018-04-07
# 2        0.1409      NaN               8.5086        left  2018-04-07
# 3        7.3118      NaN               2.2456        left  2018-04-07
# 4        7.3118      NaN               2.7498        left  2018-04-07
#
#    injury_status  subject_id     medium
# 0        healthy           4  treadmill
# 1        healthy           4  treadmill
# 2        healthy           4  treadmill
# 3        healthy           4  treadmill
# 4        healthy           4  treadmill
#
# [5 rows x 33 columns]

# %%
# rows and columns
treadmill_df.shape
# Out:
# (29814, 33)

# %%
# variables
treadmill_df.columns
# Out:
# Index(['timestamp', 'step', 'stride_pace', 'step_rate', 'stride_length',
#        'contact_time', 'flight_ratio', 'power', 'shock', 'impact_gs',
#        'braking_gs', 'footstrike_type', 'pronation_excursion_fs_mp',
#        'max_pronation_velocity', 'step_length', 'pronation_excursion_mp_to',
#        'stance_excursion_fs_mp', 'stance_excursion_mp_to', 'split_stride_pace',
#        'cycle_time', 'split_cycle_time', 'contact_ratio', 'debug_1', 'debug_2',
#        'flight_time', 'stride_angle', 'walking', 'footstrike_type_new',
#        'laterality', 'date', 'injury_status', 'subject_id', 'medium'],
#       dtype='object')

# %%
# number of observations for each subject
treadmill_df.subject_id.value_counts()
# Out:
# 12    7788
# 27    6120
# 4     5586
# 23    5413
# 16    4907
# Name: subject_id, dtype: int64

# %%
# drop unnecessary columns
treadmill_df = treadmill_df.drop(['walking', 'debug_1', 'debug_2', 'power', 'timestamp'], axis = 1)
treadmill_df.head()
# Out:
#    step  stride_pace  step_rate  stride_length  contact_time  flight_ratio  \
# 0     1       1.7251   160.2136         1.2921           460           0.0
# 1     2       1.9170   178.0415         1.2921           405           0.0
# 2     3       1.7159   159.3625         1.2921           394           0.0
# 3     4       1.3334   123.8390         1.2921           614           0.0
# 4     5       1.3760   127.7955         1.2921           599           0.0
#
#      shock  impact_gs  braking_gs  footstrike_type    ...      \
# 0   9.2403     8.8711      2.5859               12    ...
# 1   8.5985     8.1133      2.8477               13    ...
# 2   9.3279     8.8203      3.0352               12    ...
# 3  10.7894     1.8984     10.6211                3    ...
# 4   9.0301     5.6172      7.0703                4    ...
#
#    split_cycle_time  contact_ratio  flight_time  stride_angle  \
# 0               749       159.1696          -86        3.2140
# 1               674       150.5576          -68        2.0107
# 2               753       109.7493          -18        0.1409
# 3               969       172.9577         -130        7.3118
# 4               939       176.1765         -130        7.3118
#
#    footstrike_type_new  laterality        date  injury_status  subject_id  \
# 0               8.1634        left  2018-04-07        healthy           4
# 1               8.7936        left  2018-04-07        healthy           4
# 2               8.5086        left  2018-04-07        healthy           4
# 3               2.2456        left  2018-04-07        healthy           4
# 4               2.7498        left  2018-04-07        healthy           4
#
#       medium
# 0  treadmill
# 1  treadmill
# 2  treadmill
# 3  treadmill
# 4  treadmill
#
# [5 rows x 28 columns]

# %%
#check that columns were dropped
treadmill_df.shape
# Out:
# (29814, 28)

# %%
# sanity check on flight_ratio
treadmill_df['flight_ratio'].min()
# Out:
# 0.0

# %%
# drop observations where flight_ratio is less than 10 (walking)
treadmill_running_df = treadmill_df[treadmill_df.flight_ratio > 10]

#check that observations were dropped
treadmill_running_df["flight_ratio"].min()
# Out:
# 10.025700000000001

# %%
#treadmill_running_df.dtypes

# %%
treadmill_running_df.head()
# Out:
#      step  stride_pace  step_rate  stride_length  contact_time  flight_ratio  \
# 56     57       2.1873   128.6174         2.0407           350       24.8927
# 410   421       2.5812   175.4386         1.7655           299       12.5731
# 525   541       2.5062   155.0388         1.9398           339       12.4031
# 527   543       2.9097   156.2500         2.2347           309       19.5313
# 528   544       2.9298   156.0468         2.2530           319       16.9271
#
#        shock  impact_gs  braking_gs  footstrike_type    ...      \
# 56    5.2053     3.0273      4.2344               10    ...
# 410   6.6374     2.2344      6.2500                2    ...
# 525  11.3960     9.7578      5.8867                5    ...
# 527  11.5390     9.9727      5.8047                4    ...
# 528   9.4236     7.4297      5.7969                4    ...
#
#      split_cycle_time  contact_ratio  flight_time  stride_angle  \
# 56                933        60.0343          116        3.7010
# 410               684        77.6623           43        0.5886
# 525               774        77.9310           48        0.6676
# 527               768        67.3203           75        1.4145
# 528               769        70.8889           65        1.0539
#
#      footstrike_type_new  laterality        date  injury_status  subject_id  \
# 56                7.4016        left  2018-04-07        healthy           4
# 410               1.4472        left  2018-04-07        healthy           4
# 525               3.9204        left  2018-04-07        healthy           4
# 527               3.4433        left  2018-04-07        healthy           4
# 528               3.2700        left  2018-04-07        healthy           4
#
#         medium
# 56   treadmill
# 410  treadmill
# 525  treadmill
# 527  treadmill
# 528  treadmill
#
# [5 rows x 28 columns]

# %%
# group data analysis by subject
treadmill_groupby_subject = treadmill_running_df.groupby('subject_id')

# get steps for treadmill run to compare to outdoor run
treadmill_groupby_subject['step'].max()
# Out:
# subject_id
# 4     2805
# 12    3966
# 16    2722
# 23    2706
# 27    3105
# Name: step, dtype: int64

# %%
treadmill_steps = treadmill_running_df.drop(treadmill_running_df[((treadmill_running_df['subject_id'] == 4)
                                                                  & (treadmill_running_df['step'] > 1254))].index)

# %%
treadmill_steps = treadmill_steps.drop(treadmill_steps[((treadmill_steps['subject_id'] == 12)
                                                                  & (treadmill_steps['step'] > 1060))].index)

# %%
treadmill_steps = treadmill_steps.drop(treadmill_steps[((treadmill_steps['subject_id'] == 16)
                                                                  & (treadmill_steps['step'] > 1025))].index)

# %%
treadmill_steps = treadmill_steps.drop(treadmill_steps[((treadmill_steps['subject_id'] == 23)
                                                                  & (treadmill_steps['step'] > 1099))].index)

# %%
treadmill_steps = treadmill_steps.drop(treadmill_steps[((treadmill_steps['subject_id'] == 27)
                                                                  & (treadmill_steps['step'] > 1276))].index)

# %%
# group data analysis by subject
treadmill_steps_groupby_subject = treadmill_steps.groupby('subject_id')
treadmill_steps_groupby_subject['step'].max()
# Out:
# subject_id
# 4     1254
# 12    1060
# 16    1025
# 23    1099
# 27    1276
# Name: step, dtype: int64

# %%
# descriptive statistics by subject
treadmill_groupby_subject.describe(percentiles=[])
# Out:
#            braking_gs                                                 \
#                 count       mean       std     min      50%      max
# subject_id
# 4              4419.0   6.499293  0.984354  4.2344   6.3594  15.1172
# 12             6925.0  10.866667  2.878367  0.5898  11.0195  15.9922
# 16             4131.0  10.132741  2.430033  3.8438   9.7813  15.9531
# 23             5409.0   7.123099  0.865533  1.9961   7.1563  15.4102
# 27             5768.0   9.204421  3.213571  3.2969   8.6484  15.9805
#
#            contact_ratio                                 ...   stride_length  \
#                    count       mean       std      min   ...             std
# subject_id                                               ...
# 4                 4419.0  69.174952  4.249126  57.3248   ...        0.180958
# 12                6925.0  50.091340  4.887240  37.2340   ...        0.248995
# 16                4131.0  72.119921  6.783939  47.6578   ...        0.309325
# 23                5409.0  62.755982  3.704970  46.6019   ...        0.241349
# 27                5768.0  66.580236  7.758640  48.8069   ...        0.258883
#
#                                     stride_pace                              \
#                min      50%     max       count      mean       std     min
# subject_id
# 4           1.7655  2.81920  3.7547      4419.0  3.723503  0.296227  2.1873
# 12          0.8955  3.01210  3.4693      6925.0  4.152045  0.498154  0.7953
# 16          2.9347  3.72610  5.2720      4131.0  5.109179  0.508904  3.7367
# 23          1.9383  2.95240  4.1104      5409.0  4.144936  0.337158  2.6017
# 27          0.7418  2.99865  3.3232      5768.0  4.012443  0.409855  1.0147
#
#
#                 50%     max
# subject_id
# 4           3.73820  5.1231
# 12          4.23480  5.4753
# 16          4.95810  7.1068
# 23          4.08650  5.7089
# 27          4.10135  4.9662
#
# [5 rows x 138 columns]

# %%
# dataframe of means for compare
treadmill_mean = treadmill_groupby_subject.mean().add_suffix("_mean")\
                 .reset_index()

#treadmill_mean

# %%
treadmill_sd = treadmill_groupby_subject.std().add_suffix("_sd")\
               .reset_index()

treadmill_sd
# Out:
#    subject_id      step_sd  stride_pace_sd  step_rate_sd  stride_length_sd  \
# 0           4   644.777751        0.296227      4.379509          0.180958
# 1          12  1109.146899        0.498154      7.715719          0.248995
# 2          16   781.308023        0.508904      4.483081          0.309325
# 3          23   781.184882        0.337158      2.620008          0.241349
# 4          27   901.877475        0.409855      5.074730          0.258883
#
#    contact_time_sd  flight_ratio_sd  shock_sd  impact_gs_sd  braking_gs_sd  \
# 0        15.829779         2.941312  2.225381      2.450211       0.984354
# 1        23.177099         4.161686  2.939349      2.840182       2.878367
# 2        23.218967         4.710717  3.209668      3.379389       2.430033
# 3         8.899084         2.788820  2.056131      2.379779       0.865533
# 4        21.163841         5.533972  3.481362      4.074745       3.213571
#
#             ...            pronation_excursion_mp_to_sd  \
# 0           ...                                7.651240
# 1           ...                               13.271246
# 2           ...                                4.613286
# 3           ...                                6.776256
# 4           ...                                5.583853
#
#    stance_excursion_fs_mp_sd  stance_excursion_mp_to_sd  split_stride_pace_sd  \
# 0                   4.038916                   4.436419              0.296227
# 1                   6.651804                   4.619771              0.498154
# 2                   4.987866                   6.614081              0.508904
# 3                   5.381537                   7.115671              0.337158
# 4                   8.789567                  15.398988              0.409855
#
#    cycle_time_sd  split_cycle_time_sd  contact_ratio_sd  flight_time_sd  \
# 0      20.674442            20.674442          4.249126       10.642602
# 1      32.601278            32.601278          4.887240       12.631035
# 2      20.326305            20.326305          6.783939       16.460558
# 3      11.481364            11.481364          3.704970       10.725928
# 4      21.760554            21.760554          7.758640       20.486709
#
#    stride_angle_sd  footstrike_type_new_sd
# 0         0.262188                1.151091
# 1         0.567803                1.895765
# 2         0.303742                1.421542
# 3         0.336919                1.533738
# 4         0.600887                2.505027
#
# [5 rows x 24 columns]

# %%
# median descriptive statistic by subject
treadmill_median = treadmill_groupby_subject.median()\
                   .add_suffix("_median")\
                   .reset_index()

treadmill_median
# Out:
#    subject_id  step_median  stride_pace_median  step_rate_median  \
# 0           4         1664             3.73820          159.1512
# 1          12         1928             4.23480          168.0672
# 2          16         1380             4.95810          160.8579
# 3          23         1354             4.08650          166.4355
# 4          27         1539             4.10135          164.1587
#
#    stride_length_median  contact_time_median  flight_ratio_median  \
# 0               2.81920                  309              18.4416
# 1               3.01210                  235              34.0974
# 2               3.72610                  320              14.6667
# 3               2.95240                  279              22.8650
# 4               2.99865                  285              21.6508
#
#    shock_median  impact_gs_median  braking_gs_median  \
# 0       12.2223          10.26560             6.3594
# 1       16.5140          12.00780            11.0195
# 2       13.4803           8.42190             9.7813
# 3       12.4162          10.05470             7.1563
# 4       13.6088           8.49415             8.6484
#
#               ...              pronation_excursion_mp_to_median  \
# 0             ...                                        3.3345
# 1             ...                                        3.7727
# 2             ...                                        9.8020
# 3             ...                                       13.6170
# 4             ...                                       12.3567
#
#    stance_excursion_fs_mp_median  stance_excursion_mp_to_median  \
# 0                       27.46060                       59.77080
# 1                       20.52620                       41.87070
# 2                       24.02030                       55.89700
# 3                       22.07310                       60.55970
# 4                        0.86135                       67.12055
#
#    split_stride_pace_median  cycle_time_median  split_cycle_time_median  \
# 0                   3.73820                754                      754
# 1                   4.23480                714                      714
# 2                   4.95810                746                      746
# 3                   4.08650                721                      721
# 4                   4.10135                731                      731
#
#    contact_ratio_median  flight_time_median  stride_angle_median  \
# 0               68.8095                  70              0.96040
# 1               49.0982                 121              2.73950
# 2               74.2459                  55              0.46950
# 3               62.7273                  82              1.28560
# 4               64.3341                  79              1.17925
#
#    footstrike_type_new_median
# 0                     2.17370
# 1                     4.15000
# 2                     3.15420
# 3                     3.70920
# 4                     9.75455
#
# [5 rows x 24 columns]

# %%
# calculate COV
treadmill_cov = treadmill_groupby_subject\
                .aggregate(lambda x: scipy.stats.variation(x, axis=None))\
                .add_suffix("_cov")\
                .reset_index()
treadmill_cov

#treadmill_cov.to_csv("treadmill_cov.csv")
# Out:
# /Users/NatalieKramer/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
#    subject_id  step_cov  stride_pace_cov  step_rate_cov  stride_length_cov  \
# 0           4  0.387595         0.079547       0.027470           0.064599
# 1          12  0.575839         0.119969       0.045776           0.084450
# 2          16  0.581840         0.099594       0.027765           0.081540
# 3          23  0.577146         0.081335       0.015750           0.080695
# 4          27  0.582675         0.102137       0.030779           0.088716
#
#    contact_time_cov  flight_ratio_cov  shock_cov  impact_gs_cov  \
# 0          0.051414          0.161222   0.180395       0.235869
# 1          0.097361          0.124812   0.181704       0.243662
# 2          0.074587          0.288471   0.233914       0.381271
# 3          0.032015          0.121805   0.162047       0.228925
# 4          0.072925          0.273060   0.260597       0.458672
#
#    braking_gs_cov           ...             pronation_excursion_mp_to_cov  \
# 0        0.151438           ...                                 39.945814
# 1        0.264861           ...                                  1.100526
# 2        0.239791           ...                                  0.425635
# 3        0.121500           ...                                  0.469596
# 4        0.349103           ...                                  0.466154
#
#    stance_excursion_fs_mp_cov  stance_excursion_mp_to_cov  \
# 0                    0.148979                    0.073426
# 1                    0.321980                    0.109598
# 2                    0.207947                    0.119799
# 3                    0.255503                    0.115402
# 4                    1.984318                    0.220172
#
#    split_stride_pace_cov  cycle_time_cov  split_cycle_time_cov  \
# 0               0.079547        0.027440              0.027440
# 1               0.119969        0.045691              0.045691
# 2               0.099594        0.027322              0.027322
# 3               0.081335        0.015909              0.015909
# 4               0.102137        0.029866              0.029866
#
#    contact_ratio_cov  flight_time_cov  stride_angle_cov  \
# 0           0.061419         0.155175          0.273123
# 1           0.097560         0.106625          0.209509
# 2           0.094053         0.272422          0.531667
# 3           0.059032         0.129810          0.257438
# 4           0.116521         0.277440          0.524286
#
#    footstrike_type_new_cov
# 0                 0.506061
# 1                 0.460932
# 2                 0.449125
# 3                 0.383616
# 4                 0.286667
#
# [5 rows x 24 columns]

# %%
treadmill_compare = pd.merge(treadmill_mean, treadmill_sd,
                             on = "subject_id", how = 'left')

treadmill_compare = pd.merge(treadmill_compare, treadmill_cov,
                             on = "subject_id", how = 'left')

treadmill_compare
# Out:
#    subject_id    step_mean  stride_pace_mean  step_rate_mean  \
# 0           4  1663.345553          3.723503      159.408918
# 1          12  1926.001733          4.152045      168.543460
# 2          16  1342.660615          5.109179      161.444847
# 3          23  1353.406360          4.144936      166.336192
# 4          27  1547.688974          4.012443      164.861744
#
#    stride_length_mean  contact_time_mean  flight_ratio_mean  shock_mean  \
# 0            2.800926         307.854039          18.241775   12.334790
# 1            2.948203         238.035957          33.341340   16.175410
# 2            3.793059         311.263374          16.327978   13.719916
# 3            2.990602         277.936957          22.893609   12.687333
# 4            2.917873         290.189667          20.264773   13.358041
#
#    impact_gs_mean  braking_gs_mean           ...             \
# 0       10.386849         6.499293           ...
# 1       11.655420        10.866667           ...
# 2        8.862400        10.132741           ...
# 3       10.394497         7.123099           ...
# 4        8.883011         9.204421           ...
#
#    pronation_excursion_mp_to_cov  stance_excursion_fs_mp_cov  \
# 0                      39.945814                    0.148979
# 1                       1.100526                    0.321980
# 2                       0.425635                    0.207947
# 3                       0.469596                    0.255503
# 4                       0.466154                    1.984318
#
#    stance_excursion_mp_to_cov  split_stride_pace_cov  cycle_time_cov  \
# 0                    0.073426               0.079547        0.027440
# 1                    0.109598               0.119969        0.045691
# 2                    0.119799               0.099594        0.027322
# 3                    0.115402               0.081335        0.015909
# 4                    0.220172               0.102137        0.029866
#
#    split_cycle_time_cov  contact_ratio_cov  flight_time_cov  stride_angle_cov  \
# 0              0.027440           0.061419         0.155175          0.273123
# 1              0.045691           0.097560         0.106625          0.209509
# 2              0.027322           0.094053         0.272422          0.531667
# 3              0.015909           0.059032         0.129810          0.257438
# 4              0.029866           0.116521         0.277440          0.524286
#
#    footstrike_type_new_cov
# 0                 0.506061
# 1                 0.460932
# 2                 0.449125
# 3                 0.383616
# 4                 0.286667
#
# [5 rows x 70 columns]

# %% [markdown]
# #### Merge data sets

# %%
full_compare = pd.merge(treadmill_compare, outdoor_compare, 
                        on = 'subject_id', how = 'left',
                        suffixes = ('_treadmill', '_outdoor'))

full_compare
# Out:
#    subject_id  step_mean_treadmill  stride_pace_mean_treadmill  \
# 0           4          1663.345553                    3.723503
# 1          12          1926.001733                    4.152045
# 2          16          1342.660615                    5.109179
# 3          23          1353.406360                    4.144936
# 4          27          1547.688974                    4.012443
#
#    step_rate_mean_treadmill  stride_length_mean_treadmill  \
# 0                159.408918                      2.800926
# 1                168.543460                      2.948203
# 2                161.444847                      3.793059
# 3                166.336192                      2.990602
# 4                164.861744                      2.917873
#
#    contact_time_mean_treadmill  flight_ratio_mean_treadmill  \
# 0                   307.854039                    18.241775
# 1                   238.035957                    33.341340
# 2                   311.263374                    16.327978
# 3                   277.936957                    22.893609
# 4                   290.189667                    20.264773
#
#    shock_mean_treadmill  impact_gs_mean_treadmill  braking_gs_mean_treadmill  \
# 0             12.334790                 10.386849                   6.499293
# 1             16.175410                 11.655420                  10.866667
# 2             13.719916                  8.862400                  10.132741
# 3             12.687333                 10.394497                   7.123099
# 4             13.358041                  8.883011                   9.204421
#
#                 ...                 pronation_excursion_mp_to_cov_outdoor  \
# 0               ...                                             27.368492
# 1               ...                                            -10.890062
# 2               ...                                              0.866008
# 3               ...                                              0.580791
# 4               ...                                              0.340015
#
#    stance_excursion_fs_mp_cov_outdoor  stance_excursion_mp_to_cov_outdoor  \
# 0                            0.270990                            0.111133
# 1                            2.129792                            0.695743
# 2                            0.174143                            0.058082
# 3                            0.349070                            0.104770
# 4                            0.690805                            0.205615
#
#    split_stride_pace_cov_outdoor  cycle_time_cov_outdoor  \
# 0                       0.072180                0.018402
# 1                       0.408718                0.035883
# 2                       0.048928                0.019126
# 3                       0.089183                0.019732
# 4                       0.099687                0.026192
#
#    split_cycle_time_cov_outdoor  contact_ratio_cov_outdoor  \
# 0                      0.018402                   0.069873
# 1                      0.035883                   0.157319
# 2                      0.019126                   0.096655
# 3                      0.019732                   0.096296
# 4                      0.026192                   0.101453
#
#    flight_time_cov_outdoor  stride_angle_cov_outdoor  \
# 0                 0.168422                  0.320243
# 1                 0.338571                  1.517422
# 2                 0.251826                  0.482508
# 3                 0.194743                  0.353344
# 4                 0.307775                  0.697321
#
#    footstrike_type_new_cov_outdoor
# 0                         0.844574
# 1                         1.695081
# 2                         0.501797
# 3                         0.422164
# 4                         0.511644
#
# [5 rows x 139 columns]

# %%
full_compare.to_csv('full_compare.csv')

# %%
full_compare.shape
# Out:
# (5, 139)

# %%
full_cov = pd.merge(treadmill_cov, outdoor_cov, how = 'left',
                    on = "subject_id",
                    suffixes = ('_treadmill', '_outdoor'))

full_cov.head()
# Out:
#    subject_id  step_cov_treadmill  stride_pace_cov_treadmill  \
# 0           4            0.387595                   0.079547
# 1          12            0.575839                   0.119969
# 2          16            0.581840                   0.099594
# 3          23            0.577146                   0.081335
# 4          27            0.582675                   0.102137
#
#    step_rate_cov_treadmill  stride_length_cov_treadmill  \
# 0                 0.027470                     0.064599
# 1                 0.045776                     0.084450
# 2                 0.027765                     0.081540
# 3                 0.015750                     0.080695
# 4                 0.030779                     0.088716
#
#    contact_time_cov_treadmill  flight_ratio_cov_treadmill  \
# 0                    0.051414                    0.161222
# 1                    0.097361                    0.124812
# 2                    0.074587                    0.288471
# 3                    0.032015                    0.121805
# 4                    0.072925                    0.273060
#
#    shock_cov_treadmill  impact_gs_cov_treadmill  braking_gs_cov_treadmill  \
# 0             0.180395                 0.235869                  0.151438
# 1             0.181704                 0.243662                  0.264861
# 2             0.233914                 0.381271                  0.239791
# 3             0.162047                 0.228925                  0.121500
# 4             0.260597                 0.458672                  0.349103
#
#                 ...                 pronation_excursion_mp_to_cov_outdoor  \
# 0               ...                                             27.368492
# 1               ...                                            -10.890062
# 2               ...                                              0.866008
# 3               ...                                              0.580791
# 4               ...                                              0.340015
#
#    stance_excursion_fs_mp_cov_outdoor  stance_excursion_mp_to_cov_outdoor  \
# 0                            0.270990                            0.111133
# 1                            2.129792                            0.695743
# 2                            0.174143                            0.058082
# 3                            0.349070                            0.104770
# 4                            0.690805                            0.205615
#
#    split_stride_pace_cov_outdoor  cycle_time_cov_outdoor  \
# 0                       0.072180                0.018402
# 1                       0.408718                0.035883
# 2                       0.048928                0.019126
# 3                       0.089183                0.019732
# 4                       0.099687                0.026192
#
#    split_cycle_time_cov_outdoor  contact_ratio_cov_outdoor  \
# 0                      0.018402                   0.069873
# 1                      0.035883                   0.157319
# 2                      0.019126                   0.096655
# 3                      0.019732                   0.096296
# 4                      0.026192                   0.101453
#
#    flight_time_cov_outdoor  stride_angle_cov_outdoor  \
# 0                 0.168422                  0.320243
# 1                 0.338571                  1.517422
# 2                 0.251826                  0.482508
# 3                 0.194743                  0.353344
# 4                 0.307775                  0.697321
#
#    footstrike_type_new_cov_outdoor
# 0                         0.844574
# 1                         1.695081
# 2                         0.501797
# 3                         0.422164
# 4                         0.511644
#
# [5 rows x 47 columns]
